# %% [markdown]
# # <center>Produire une étude de marché avec Python

# %% [markdown]
# **Scénario :**<p>
# Vous travaillez chez La poule qui chante, une entreprise française d’agroalimentaire. Elle souhaite se développer à l'international.<p>
# L'international, oui, mais pour l'instant, le champ des possibles est bien large : aucun pays particulier ni aucun continent n'est pour le moment choisi. Tous les pays sont envisageables !

# %% [markdown]
# ---

# %% [markdown]
# **Compétences évaluées :**<p>
#
# - Effectuer un clustering simple :<p>
#     - clustering avec avec la méthode ACP (Analyse en Composantes Principales)<p>
# - Explorer des données pour synthétiser des variables :<p>
#     - clustering avec avec la méthode CAH (Classification Ascendante Hiérarchique)<p>
#     - clustering avec la méthode k-means<p>

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from functions import *

# %% [markdown]
# Données en open data issues du site de la [FAO (Food and Agriculture Organization)](https://www.fao.org/faostat/fr/#data/)

# %% [markdown]
# ## Fichier Population

# %%
pop = pd.read_csv('Population_2000_2018.csv')

# %%
pop.shape
# Out:
# (4411, 15)

# %%
#population du pays, exprimée en milliers d’habitants a passser en millions  * 1000
pop['Valeur'] = pop['Valeur'] * 1000

# %%
#renomer la colonne valeur (plus en milliers mais en millions)
pop = pop.rename(columns={"Valeur": "Population"})

# %%
#evolution sur 5 ans 2013=>2017
pop=pop.query('[2013, 2017] in Année')

# %%
#on ne garde que les colonnes utiles
pop=pop[['Zone','Année','Population']]

# %%
pop=pd.pivot_table(pop, values="Population", index=["Zone"], columns=["Année"])
pop=pop.set_axis(['2013', '2017'], axis = 1)

# %%
#pourcentage d'évolution sur 5ans entre 2013 et 2017
pop['Évolution Population(%)'] = round(((pop["2017"] - pop["2013"]))/ pop["2013"] *100, 2)

# %%
#on ne garde que les colonnes utiles
pop=pop[['Évolution Population(%)']]

# %%
pop.head()
# Out:
#                 Évolution Population(%)
# Zone
# Afghanistan                       12.48
# Afrique du Sud                     6.19
# Albanie                           -0.68
# Algérie                            8.52
# Allemagne                          1.83

# %% [markdown]
# ## Fichier Disponibilite Alimentaire

# %%
da = pd.read_csv('DisponibiliteAlimentaire_2017.csv')

# %%
da.shape
# Out:
# (176600, 14)

# %%
#on de garde que la viande de volailles
da=da[(da["Produit"] == "Viande de Volailles")]

# %%
#on ne garde pas l'élément "Aliments pour animaux"
da=da.loc[~(da['Élément']== "Aliments pour animaux")]

# %%
#on ne garde pas l'élément "Semences"
da=da.loc[~(da['Élément']== "Semences")]

# %%
#création d'une colonne element + unité
da['Element'] = da['Élément'].map(str) + '-' + da['Unité']

# %%
#je ne garde que les colonnes utiles
da=da[['Zone','Element','Valeur']]

# %%
#je pivot mes données pour que les élements deviennent mes colonnes
da = da.pivot(index="Zone", columns="Element", values="Valeur")

# %%
da.head()
# Out:
# Element         Alimentation pour touristes-Milliers de tonnes  \
# Zone
# Afghanistan                                                NaN
# Afrique du Sud                                             0.0
# Albanie                                                    NaN
# Algérie                                                    0.0
# Allemagne                                                  NaN
#
# Element         Autres utilisations (non alimentaire)-Milliers de tonnes  \
# Zone
# Afghanistan                                                   NaN
# Afrique du Sud                                                NaN
# Albanie                                                       NaN
# Algérie                                                       NaN
# Allemagne                                                     NaN
#
# Element         Disponibilité alimentaire (Kcal/personne/jour)-Kcal/personne/jour  \
# Zone
# Afghanistan                                                   5.0
# Afrique du Sud                                              143.0
# Albanie                                                      85.0
# Algérie                                                      22.0
# Allemagne                                                    71.0
#
# Element         Disponibilité alimentaire en quantité (kg/personne/an)-kg  \
# Zone
# Afghanistan                                                  1.53
# Afrique du Sud                                              35.69
# Albanie                                                     16.36
# Algérie                                                      6.38
# Allemagne                                                   19.47
#
# Element         Disponibilité de matière grasse en quantité (g/personne/jour)-g/personne/jour  \
# Zone
# Afghanistan                                                  0.33
# Afrique du Sud                                               9.25
# Albanie                                                      6.45
# Algérie                                                      1.50
# Allemagne                                                    4.16
#
# Element         Disponibilité de protéines en quantité (g/personne/jour)-g/personne/jour  \
# Zone
# Afghanistan                                                  0.54
# Afrique du Sud                                              14.11
# Albanie                                                      6.26
# Algérie                                                      1.97
# Allemagne                                                    7.96
#
# Element         Disponibilité intérieure-Milliers de tonnes  \
# Zone
# Afghanistan                                            57.0
# Afrique du Sud                                       2118.0
# Albanie                                                47.0
# Algérie                                               277.0
# Allemagne                                            1739.0
#
# Element         Exportations - Quantité-Milliers de tonnes  \
# Zone
# Afghanistan                                            NaN
# Afrique du Sud                                        63.0
# Albanie                                                0.0
# Algérie                                                0.0
# Allemagne                                            646.0
#
# Element         Importations - Quantité-Milliers de tonnes  \
# Zone
# Afghanistan                                           29.0
# Afrique du Sud                                       514.0
# Albanie                                               38.0
# Algérie                                                2.0
# Allemagne                                            842.0
#
# Element         Nourriture-Milliers de tonnes  Pertes-Milliers de tonnes  \
# Zone
# Afghanistan                              55.0                        2.0
# Afrique du Sud                         2035.0                       83.0
# Albanie                                  47.0                        NaN
# Algérie                                 264.0                       13.0
# Allemagne                              1609.0                        NaN
#
# Element         Production-Milliers de tonnes  Résidus-Milliers de tonnes  \
# Zone
# Afghanistan                              28.0                         0.0
# Afrique du Sud                         1667.0                         0.0
# Albanie                                  13.0                         0.0
# Algérie                                 275.0                         0.0
# Allemagne                              1514.0                       -38.0
#
# Element         Traitement-Milliers de tonnes  \
# Zone
# Afghanistan                               NaN
# Afrique du Sud                            NaN
# Albanie                                   NaN
# Algérie                                   NaN
# Allemagne                               167.0
#
# Element         Variation de stock-Milliers de tonnes
# Zone
# Afghanistan                                       0.0
# Afrique du Sud                                   -0.0
# Albanie                                           4.0
# Algérie                                           0.0
# Allemagne                                       -29.0

# %% [markdown]
# ## Fichier PIB par habitant

# %% [markdown]
# #### Enrichissement des données en intégrant une variable PIB par habitant

# %% [markdown]
# Ajouter un dimension économique</p>
# https://www.fao.org/faostat/fr/#data/

# %%
#données l'année 2013 a 2017 issu du site de la FAO
pib = pd.read_csv('PIB_par_habitant_13-17.csv')

# %%
pib.shape
# Out:
# (1055, 15)

# %%
pib = pib.rename(columns={"Valeur": "PIB_US_$_par_habitant"})

# %%
#je ne garde que les années 2013 et 2017
pib=pib.query('[2013, 2017] in Année')

# %%
#on ne garde que les colonnes utiles
pib=pib[['Zone','Année','PIB_US_$_par_habitant']]

# %%
pib=pd.pivot_table(pib, values="PIB_US_$_par_habitant", index=["Zone"], columns=["Année"])
pib=pib.set_axis(['2013', '2017'], axis = 1)

# %%
#pourcentage d'évolution sur 5ans entre 2013 et 2017
pib['Évolution Pib(%)'] = round(((pib["2017"] - pib["2013"]))/ pib["2013"] *100, 2)

# %%
pib=pib[['Évolution Pib(%)']]

# %%
pib.head()
# Out:
#                 Évolution Pib(%)
# Zone
# Afghanistan               -15.62
# Afrique du Sud            -10.36
# Albanie                     2.60
# Algérie                   -25.27
# Allemagne                  -3.11

# %%
pib.shape
# Out:
# (211, 1)

# %% [markdown]
# ## Fichier Stabilité Politique

# %% [markdown]
# #### Enrichissement des données en intégrant une variable stabilité politique

# %% [markdown]
# Ajouter un dimension politique<p>
# http://info.worldbank.org/governance/wgi/

# %%
#données l'année 2017 issu du site de la FAO
pol = pd.read_csv('stabilité_politique.csv')

# %%
pol.shape
# Out:
# (197, 15)

# %%
pol = pol.rename(columns={"Valeur": "Stabilité politique"})

# %%
#je ne garde que les colonnes utiles
pol=pol[['Zone','Stabilité politique']]

# %%
pol.head()
# Out:
#              Zone  Stabilité politique
# 0     Afghanistan                -2.80
# 1  Afrique du Sud                -0.28
# 2         Albanie                 0.38
# 3         Algérie                -0.92
# 4       Allemagne                 0.59

# %% [markdown]
# #### Fusion des dataset

# %%
# fusion des dataset da et pop
data = pd.merge(da, pop, how="left", on="Zone")

# %%
data.shape
# Out:
# (172, 16)

# %%
# ajout du dataset pib
data = pd.merge(data, pib, how="left", on="Zone")

# %%
data.shape
# Out:
# (172, 17)

# %%
# ajout du dataset pol
data = pd.merge(data, pol, how="left", on="Zone")

# %%
#on ne vas pas exporter en 'France'
data = data[data['Zone'] != 'France']

# %%
data.shape
# Out:
# (171, 19)

# %%
# je defini la zone comme index (pour n'avoir uniquement que des données quantitatives dans les variables)
data.set_index('Zone', inplace = True)

# %%
data.head()
# Out:
#                 Alimentation pour touristes-Milliers de tonnes  \
# Zone
# Afghanistan                                                NaN
# Afrique du Sud                                             0.0
# Albanie                                                    NaN
# Algérie                                                    0.0
# Allemagne                                                  NaN
#
#                 Autres utilisations (non alimentaire)-Milliers de tonnes  \
# Zone
# Afghanistan                                                   NaN
# Afrique du Sud                                                NaN
# Albanie                                                       NaN
# Algérie                                                       NaN
# Allemagne                                                     NaN
#
#                 Disponibilité alimentaire (Kcal/personne/jour)-Kcal/personne/jour  \
# Zone
# Afghanistan                                                   5.0
# Afrique du Sud                                              143.0
# Albanie                                                      85.0
# Algérie                                                      22.0
# Allemagne                                                    71.0
#
#                 Disponibilité alimentaire en quantité (kg/personne/an)-kg  \
# Zone
# Afghanistan                                                  1.53
# Afrique du Sud                                              35.69
# Albanie                                                     16.36
# Algérie                                                      6.38
# Allemagne                                                   19.47
#
#                 Disponibilité de matière grasse en quantité (g/personne/jour)-g/personne/jour  \
# Zone
# Afghanistan                                                  0.33
# Afrique du Sud                                               9.25
# Albanie                                                      6.45
# Algérie                                                      1.50
# Allemagne                                                    4.16
#
#                 Disponibilité de protéines en quantité (g/personne/jour)-g/personne/jour  \
# Zone
# Afghanistan                                                  0.54
# Afrique du Sud                                              14.11
# Albanie                                                      6.26
# Algérie                                                      1.97
# Allemagne                                                    7.96
#
#                 Disponibilité intérieure-Milliers de tonnes  \
# Zone
# Afghanistan                                            57.0
# Afrique du Sud                                       2118.0
# Albanie                                                47.0
# Algérie                                               277.0
# Allemagne                                            1739.0
#
#                 Exportations - Quantité-Milliers de tonnes  \
# Zone
# Afghanistan                                            NaN
# Afrique du Sud                                        63.0
# Albanie                                                0.0
# Algérie                                                0.0
# Allemagne                                            646.0
#
#                 Importations - Quantité-Milliers de tonnes  \
# Zone
# Afghanistan                                           29.0
# Afrique du Sud                                       514.0
# Albanie                                               38.0
# Algérie                                                2.0
# Allemagne                                            842.0
#
#                 Nourriture-Milliers de tonnes  Pertes-Milliers de tonnes  \
# Zone
# Afghanistan                              55.0                        2.0
# Afrique du Sud                         2035.0                       83.0
# Albanie                                  47.0                        NaN
# Algérie                                 264.0                       13.0
# Allemagne                              1609.0                        NaN
#
#                 Production-Milliers de tonnes  Résidus-Milliers de tonnes  \
# Zone
# Afghanistan                              28.0                         0.0
# Afrique du Sud                         1667.0                         0.0
# Albanie                                  13.0                         0.0
# Algérie                                 275.0                         0.0
# Allemagne                              1514.0                       -38.0
#
#                 Traitement-Milliers de tonnes  \
# Zone
# Afghanistan                               NaN
# Afrique du Sud                            NaN
# Albanie                                   NaN
# Algérie                                   NaN
# Allemagne                               167.0
#
#                 Variation de stock-Milliers de tonnes  \
# Zone
# Afghanistan                                       0.0
# Afrique du Sud                                   -0.0
# Albanie                                           4.0
# Algérie                                           0.0
# Allemagne                                       -29.0
#
#                 Évolution Population(%)  Évolution Pib(%)  Stabilité politique
# Zone
# Afghanistan                       12.48            -15.62                -2.80
# Afrique du Sud                     6.19            -10.36                -0.28
# Albanie                           -0.68              2.60                 0.38
# Algérie                            8.52            -25.27                -0.92
# Allemagne                          1.83             -3.11                 0.59

# %%
#je remplace toute les données manquantes par la moyenne
data=data.fillna(data.mean())

# %%
data.head()
# Out:
#                 Alimentation pour touristes-Milliers de tonnes  \
# Zone
# Afghanistan                                           0.217949
# Afrique du Sud                                        0.000000
# Albanie                                               0.217949
# Algérie                                               0.000000
# Allemagne                                             0.217949
#
#                 Autres utilisations (non alimentaire)-Milliers de tonnes  \
# Zone
# Afghanistan                                             44.117647
# Afrique du Sud                                          44.117647
# Albanie                                                 44.117647
# Algérie                                                 44.117647
# Allemagne                                               44.117647
#
#                 Disponibilité alimentaire (Kcal/personne/jour)-Kcal/personne/jour  \
# Zone
# Afghanistan                                                   5.0
# Afrique du Sud                                              143.0
# Albanie                                                      85.0
# Algérie                                                      22.0
# Allemagne                                                    71.0
#
#                 Disponibilité alimentaire en quantité (kg/personne/an)-kg  \
# Zone
# Afghanistan                                                  1.53
# Afrique du Sud                                              35.69
# Albanie                                                     16.36
# Algérie                                                      6.38
# Allemagne                                                   19.47
#
#                 Disponibilité de matière grasse en quantité (g/personne/jour)-g/personne/jour  \
# Zone
# Afghanistan                                                  0.33
# Afrique du Sud                                               9.25
# Albanie                                                      6.45
# Algérie                                                      1.50
# Allemagne                                                    4.16
#
#                 Disponibilité de protéines en quantité (g/personne/jour)-g/personne/jour  \
# Zone
# Afghanistan                                                  0.54
# Afrique du Sud                                              14.11
# Albanie                                                      6.26
# Algérie                                                      1.97
# Allemagne                                                    7.96
#
#                 Disponibilité intérieure-Milliers de tonnes  \
# Zone
# Afghanistan                                            57.0
# Afrique du Sud                                       2118.0
# Albanie                                                47.0
# Algérie                                               277.0
# Allemagne                                            1739.0
#
#                 Exportations - Quantité-Milliers de tonnes  \
# Zone
# Afghanistan                                     129.432836
# Afrique du Sud                                   63.000000
# Albanie                                           0.000000
# Algérie                                           0.000000
# Allemagne                                       646.000000
#
#                 Importations - Quantité-Milliers de tonnes  \
# Zone
# Afghanistan                                           29.0
# Afrique du Sud                                       514.0
# Albanie                                               38.0
# Algérie                                                2.0
# Allemagne                                            842.0
#
#                 Nourriture-Milliers de tonnes  Pertes-Milliers de tonnes  \
# Zone
# Afghanistan                              55.0                    2.00000
# Afrique du Sud                         2035.0                   83.00000
# Albanie                                  47.0                   43.58209
# Algérie                                 264.0                   13.00000
# Allemagne                              1609.0                   43.58209
#
#                 Production-Milliers de tonnes  Résidus-Milliers de tonnes  \
# Zone
# Afghanistan                              28.0                         0.0
# Afrique du Sud                         1667.0                         0.0
# Albanie                                  13.0                         0.0
# Algérie                                 275.0                         0.0
# Allemagne                              1514.0                       -38.0
#
#                 Traitement-Milliers de tonnes  \
# Zone
# Afghanistan                         24.888889
# Afrique du Sud                      24.888889
# Albanie                             24.888889
# Algérie                             24.888889
# Allemagne                          167.000000
#
#                 Variation de stock-Milliers de tonnes  \
# Zone
# Afghanistan                                       0.0
# Afrique du Sud                                   -0.0
# Albanie                                           4.0
# Algérie                                           0.0
# Allemagne                                       -29.0
#
#                 Évolution Population(%)  Évolution Pib(%)  Stabilité politique
# Zone
# Afghanistan                       12.48            -15.62                -2.80
# Afrique du Sud                     6.19            -10.36                -0.28
# Albanie                           -0.68              2.60                 0.38
# Algérie                            8.52            -25.27                -0.92
# Allemagne                          1.83             -3.11                 0.59

# %%
data.shape
# Out:
# (171, 18)

# %%
#je selectionne certaines variables
df=data[['Importations - Quantité-Milliers de tonnes','Disponibilité alimentaire (Kcal/personne/jour)-Kcal/personne/jour','Évolution Population(%)','Évolution Pib(%)','Stabilité politique']]

# %%
df=df.rename(columns={'Importations - Quantité-Milliers de tonnes':'Importations (Milliers de tonnes)','Disponibilité alimentaire (Kcal/personne/jour)-Kcal/personne/jour': 'Disponibilité alimentaire (Kcal/personne/jour)'})

# %%
#Vérification d'éventuelles valeurs manquantes et/ou en doubles dans l'échantillon
print(df.duplicated().sum())
print(df.isna().sum())
# Out:
# 0
# Importations (Milliers de tonnes)                 0
# Disponibilité alimentaire (Kcal/personne/jour)    0
# Évolution Population(%)                           0
# Évolution Pib(%)                                  0
# Stabilité politique                               0
# dtype: int64

# %%
df.head()
# Out:
#                 Importations (Milliers de tonnes)  \
# Zone
# Afghanistan                                  29.0
# Afrique du Sud                              514.0
# Albanie                                      38.0
# Algérie                                       2.0
# Allemagne                                   842.0
#
#                 Disponibilité alimentaire (Kcal/personne/jour)  \
# Zone
# Afghanistan                                                5.0
# Afrique du Sud                                           143.0
# Albanie                                                   85.0
# Algérie                                                   22.0
# Allemagne                                                 71.0
#
#                 Évolution Population(%)  Évolution Pib(%)  Stabilité politique
# Zone
# Afghanistan                       12.48            -15.62                -2.80
# Afrique du Sud                     6.19            -10.36                -0.28
# Albanie                           -0.68              2.60                 0.38
# Algérie                            8.52            -25.27                -0.92
# Allemagne                          1.83             -3.11                 0.59

# %% [markdown]
# mes données correspondent a 171 pays et 5 variables :<p>
#  - Importations et Disponibilité alimentaire =>l'alimentation<p>
#  - Évolution de la population => Social<p>
#  - Évolution du PIB => Economique<p>
#  - Stabilité politique => Politique<p>

# %%
df.describe().round(2)
# Out:
#        Importations (Milliers de tonnes)  \
# count                             171.00
# mean                               87.07
# std                               183.34
# min                                 0.00
# 25%                                 3.00
# 50%                                16.00
# 75%                                83.00
# max                              1069.00
#
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# count                                          171.00
# mean                                            74.46
# std                                             60.73
# min                                              0.00
# 25%                                             22.00
# 50%                                             63.00
# 75%                                            106.00
# max                                            243.00
#
#        Évolution Population(%)  Évolution Pib(%)  Stabilité politique
# count                   171.00            171.00               171.00
# mean                      5.50              0.35                -0.07
# std                       5.02             19.77                 0.89
# min                      -5.43            -47.47                -2.94
# 25%                       1.94             -9.50                -0.62
# 50%                       4.88             -0.26                -0.04
# 75%                       9.09             11.50                 0.65
# max                      23.94             73.44                 1.59

# %% [markdown]
# #### Correlation
#
#    - La couleur foncée représente une corrélation positive,
#    - La couleur claire/blanche correspond à une corrélation négative.

# %%
#recherche de corrélations entre les variables
fig, ax = plt.subplots(figsize=(16,8))
sb.heatmap(df.corr(), ax=ax,annot=True,cmap='Reds',linewidth=0.5,mask= np.triu(df.corr()))
ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize = 16)
ax.set_yticklabels(ax.get_ymajorticklabels(), fontsize = 16)

plt.title('Heatmap affichant les relations entre les caractéristiques des données',fontsize=18)
plt.savefig("recherce de correlation.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# Il n'y a uncune corélation forte entre nos differentes variables,elles sont independantes.

# %% [markdown]
# ## **Réaliser une Classification ascendante hiérarchique ( CAH )**

# %%
from scipy.cluster.hierarchy import dendrogram , linkage,ward, fcluster
from sklearn import preprocessing

# %%
# préparation des données pour le clustering
X_cah=df.values

# %%
#générer la matrice des liens 
Z = linkage(X_cah,method='ward',metric='euclidean')

# %%
# génération et affichage du dendrogramme
plt.figure(figsize=(20,12))
plt.title("CAH") 
dendrogram(Z,labels=df.index,color_threshold=400)#decoupage du dendrogramme a la hauteur 400
plt.savefig("Dendrogramme_400.png", bbox_inches='tight')
plt.show()

# %%
#découpage à la hauteur t = 400 ==> 7 groupes obtenus
groupes_cah = fcluster(Z,t=400,criterion='distance')
print(np.unique(groupes_cah).size, "groupes constitués"," "+ str(np.unique(groupes_cah)))
# Out:
# 7 groupes constitués  [1 2 3 4 5 6 7]

# %%
#index triés des groupes
idg= np.argsort(groupes_cah)

# %%
#affichage des pays par groupe
for i in range(1,8):
    print(f"Group {i}:")
    print(", ".join(df.index[groupes_cah == i].sort_values()))
    print(" ")
# Out:
# Group 1:
# Antigua-et-Barbuda, Argentine, Australie, Bahamas, Barbade, Bolivie (État plurinational de), Brésil, Chine - RAS de Macao, Dominique, Grenade, Guyana, Israël, Jamaïque, Nouvelle-Calédonie, Nouvelle-Zélande, Polynésie française, Saint-Kitts-et-Nevis, Saint-Vincent-et-les Grenadines, Sainte-Lucie, Samoa, Trinité-et-Tobago
#
# Group 2:
# Autriche, Bulgarie, Bénin, Canada, Chili, Chine, Taiwan Province de, Congo, Danemark, Espagne, Fédération de Russie, Ghana, Grèce, Guatemala, Haïti, Irlande, Italie, Kazakhstan, Koweït, Oman, Ouzbékistan, Roumanie, République de Corée, Suède, Tchéquie, Ukraine, Yémen, Égypte, États-Unis d'Amérique
#
# Group 3:
# Afghanistan, Algérie, Bangladesh, Bosnie-Herzégovine, Botswana, Burkina Faso, Cambodge, Cameroun, Croatie, Côte d'Ivoire, Djibouti, Eswatini, Gambie, Guinée, Guinée-Bissau, Inde, Indonésie, Kenya, Kirghizistan, Lesotho, Liban, Madagascar, Malawi, Maldives, Mali, Mauritanie, Mongolie, Monténégro, Mozambique, Namibie, Niger, Nigéria, Népal, Ouganda, Pakistan, Paraguay, Rwanda, République centrafricaine, République de Moldova, République populaire démocratique de Corée, République-Unie de Tanzanie, Sao Tomé-et-Principe, Serbie, Sierra Leone, Soudan, Sri Lanka, Sénégal, Tadjikistan, Tchad, Thaïlande, Timor-Leste, Togo, Turkménistan, Uruguay, Vanuatu, Zambie, Zimbabwe, Éthiopie, Îles Salomon
#
# Group 4:
# Albanie, Arménie, Azerbaïdjan, Belize, Bélarus, Cabo Verde, Chypre, Colombie, Costa Rica, El Salvador, Estonie, Fidji, Finlande, Gabon, Géorgie, Honduras, Hongrie, Iran (République islamique d'), Islande, Jordanie, Kiribati, Lettonie, Libéria, Lituanie, Luxembourg, Macédoine du Nord, Malaisie, Malte, Maroc, Maurice, Myanmar, Nicaragua, Norvège, Panama, Pologne, Portugal, Pérou, République dominicaine, République démocratique populaire lao, Slovaquie, Slovénie, Suisse, Suriname, Tunisie, Turquie, Venezuela (République bolivarienne du), Équateur
#
# Group 5:
# Allemagne, Arabie saoudite, Chine - RAS de Hong-Kong, Japon, Mexique, Royaume-Uni de Grande-Bretagne et d'Irlande du Nord
#
# Group 6:
# Angola, Belgique, Cuba, Philippines, Viet Nam
#
# Group 7:
# Afrique du Sud, Chine, continentale, Iraq, Pays-Bas, Émirats arabes unis

# %%
#création et intégration d'une colonne "groupe" dans le df
df_groupes_cah = pd.DataFrame(df.index[idg], groupes_cah[idg]).reset_index()
df_groupes_cah = df_groupes_cah.rename(columns={'index':'Groupe'})
df_cah = pd.merge(df, df_groupes_cah, on='Zone')

# %%
#Affichage du nombre de pays par groupe
df_groupes_cah.groupby('Groupe').count()
# Out:
#         Zone
# Groupe
# 1         21
# 2         28
# 3         59
# 4         47
# 5          6
# 6          5
# 7          5

# %%
#Affichage du nombre de pays par groupe
df_groupes_cah.groupby('Groupe').count().plot.bar(rot=0)
plt.title("Nombre de pays par groupe - CAH")
plt.savefig("CAH_nb_pays.png")
plt.show()

# %%
#création d'un sous-ensemble pour chaque groupe
cah_1 = df_cah[df_cah['Groupe'] == 1]
cah_2 = df_cah[df_cah['Groupe'] == 2]
cah_3 = df_cah[df_cah['Groupe'] == 3]
cah_4 = df_cah[df_cah['Groupe'] == 4]
cah_5 = df_cah[df_cah['Groupe'] == 5]
cah_6 = df_cah[df_cah['Groupe'] == 6]
cah_7 = df_cah[df_cah['Groupe'] == 7]

# %%
#Comparaison des groupes en fonction de leur moyenne par variables
styles = [dict(selector="caption", props=[("font-size", "150%"),("font-weight", "bold")])]
df_cah.groupby('Groupe').mean().style.set_caption("Heatmap avec les clusters de pays et les différentes variables").set_table_styles(styles).format(precision=2).background_gradient(cmap = 'Reds')
# Out:
# <style type="text/css">
# #T_2216a caption {
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_2216a_row0_col0, #T_2216a_row0_col2, #T_2216a_row1_col3, #T_2216a_row2_col0, #T_2216a_row2_col1, #T_2216a_row2_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2216a_row0_col1, #T_2216a_row0_col4, #T_2216a_row2_col2, #T_2216a_row4_col0, #T_2216a_row5_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2216a_row0_col3 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_2216a_row1_col0 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_2216a_row1_col1 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_2216a_row1_col2 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_2216a_row1_col4 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_2216a_row2_col3 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_2216a_row3_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_2216a_row3_col1 {
#   background-color: #fc8d6d;
#   color: #f1f1f1;
# }
# #T_2216a_row3_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_2216a_row3_col3 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_2216a_row3_col4 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_2216a_row4_col1 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_2216a_row4_col2 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_2216a_row4_col3 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_2216a_row4_col4 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_2216a_row5_col0 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_2216a_row5_col1 {
#   background-color: #fdcbb6;
#   color: #000000;
# }
# #T_2216a_row5_col2, #T_2216a_row6_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_2216a_row5_col4 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_2216a_row6_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_2216a_row6_col2 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_2216a_row6_col3 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_2216a_row6_col4 {
#   background-color: #fcae92;
#   color: #000000;
# }
# </style>
# <table id="T_2216a">
#   <caption>Heatmap avec les clusters de pays et les différentes variables</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2216a_level0_col0" class="col_heading level0 col0" >Importations (Milliers de tonnes)</th>
#       <th id="T_2216a_level0_col1" class="col_heading level0 col1" >Disponibilité alimentaire (Kcal/personne/jour)</th>
#       <th id="T_2216a_level0_col2" class="col_heading level0 col2" >Évolution Population(%)</th>
#       <th id="T_2216a_level0_col3" class="col_heading level0 col3" >Évolution Pib(%)</th>
#       <th id="T_2216a_level0_col4" class="col_heading level0 col4" >Stabilité politique</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Groupe</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2216a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2216a_row0_col0" class="data row0 col0" >10.19</td>
#       <td id="T_2216a_row0_col1" class="data row0 col1" >187.19</td>
#       <td id="T_2216a_row0_col2" class="data row0 col2" >3.44</td>
#       <td id="T_2216a_row0_col3" class="data row0 col3" >4.11</td>
#       <td id="T_2216a_row0_col4" class="data row0 col4" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_2216a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2216a_row1_col0" class="data row1 col0" >128.22</td>
#       <td id="T_2216a_row1_col1" class="data row1 col1" >81.75</td>
#       <td id="T_2216a_row1_col2" class="data row1 col2" >4.86</td>
#       <td id="T_2216a_row1_col3" class="data row1 col3" >-9.92</td>
#       <td id="T_2216a_row1_col4" class="data row1 col4" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_2216a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2216a_row2_col0" class="data row2 col0" >8.07</td>
#       <td id="T_2216a_row2_col1" class="data row2 col1" >18.14</td>
#       <td id="T_2216a_row2_col2" class="data row2 col2" >8.25</td>
#       <td id="T_2216a_row2_col3" class="data row2 col3" >4.49</td>
#       <td id="T_2216a_row2_col4" class="data row2 col4" >-0.54</td>
#     </tr>
#     <tr>
#       <th id="T_2216a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2216a_row3_col0" class="data row3 col0" >29.21</td>
#       <td id="T_2216a_row3_col1" class="data row3 col1" >84.51</td>
#       <td id="T_2216a_row3_col2" class="data row3 col2" >3.60</td>
#       <td id="T_2216a_row3_col3" class="data row3 col3" >0.04</td>
#       <td id="T_2216a_row3_col4" class="data row3 col4" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_2216a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2216a_row4_col0" class="data row4 col0" >881.83</td>
#       <td id="T_2216a_row4_col1" class="data row4 col1" >123.67</td>
#       <td id="T_2216a_row4_col2" class="data row4 col2" >3.69</td>
#       <td id="T_2216a_row4_col3" class="data row4 col3" >-4.10</td>
#       <td id="T_2216a_row4_col4" class="data row4 col4" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_2216a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2216a_row5_col0" class="data row5 col0" >293.40</td>
#       <td id="T_2216a_row5_col1" class="data row5 col1" >51.40</td>
#       <td id="T_2216a_row5_col2" class="data row5 col2" >5.62</td>
#       <td id="T_2216a_row5_col3" class="data row5 col3" >6.16</td>
#       <td id="T_2216a_row5_col4" class="data row5 col4" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_2216a_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2216a_row6_col0" class="data row6 col0" >495.40</td>
#       <td id="T_2216a_row6_col1" class="data row6 col1" >94.20</td>
#       <td id="T_2216a_row6_col2" class="data row6 col2" >5.15</td>
#       <td id="T_2216a_row6_col3" class="data row6 col3" >-4.54</td>
#       <td id="T_2216a_row6_col4" class="data row6 col4" >-0.22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Caractéristique des pays du groupe :<p>
#  1 - forte Disponibilité alimentaire et faible importation, forte stabilité_politique et bon Évolution_Pib<p>
#  2 - baisse importante du  Pib(%)<p>
#  3 - forte Evolution Population et bon Évolution_Pib et très faible Disponibilité alimentaire et Stabilité politique<p>
#  5 - forte Importations et bon Disponibilité alimentaire, bonne Stabilité politique<p>
#  6 - fort Évolution_Pib et Importations au dessus de la moyenne<p>
#  7 - importations importante<p>

# %% [markdown]
# ### Analyse bivariée : Boxplot des variables en fonction des groupes

# %%
#Comparaison visuelle des groupes par Boxplot
plt.figure(figsize=(15, 15))

plt.subplot(321)
sb.boxplot(data=df_cah, x='Groupe', y='Importations (Milliers de tonnes)').set_title('Importations par groupe')

plt.subplot(322)
sb.boxplot(data=df_cah, x='Groupe', y='Disponibilité alimentaire (Kcal/personne/jour)').set_title('Disponibilité alimentaire par groupe')

plt.subplot(323)
sb.boxplot(data=df_cah, x='Groupe', y='Évolution Population(%)').set_title('Évolution Population par groupe')

plt.subplot(324)
sb.boxplot(data=df_cah, x='Groupe', y='Évolution Pib(%)').set_title('Évolution du PIB par groupe')

plt.subplot(325)
sb.boxplot(data=df_cah, x='Groupe', y='Stabilité politique').set_title('Stabilité politique par groupe')

plt.show(block=False)

# %%
plt.figure(figsize=(15, 15))
sb.boxplot(data=df_cah, x='Groupe', y='Importations (Milliers de tonnes)').set_title('Importations par groupe')
plt.savefig("Importations_Boxplot.png")
plt.show()

# %%
#les pays du groupes 5  ont des importations très supérieur a leurs productions(grand besoin) et ont une bonne stabilité politique
print("Pays du groupe 5:")
print(cah_5['Zone'].unique())
# Out:
# Pays du groupe 5:
# ['Allemagne' 'Arabie saoudite' 'Chine - RAS de Hong-Kong' 'Japon'
#  'Mexique' "Royaume-Uni de Grande-Bretagne et d'Irlande du Nord"]

# %%
#definir la colone Zone comme index
cah_5.set_index('Zone', inplace=True)

# %%
# garder toutes les colonnes sauf "Groupe" et classer par "Importations"
selection=cah_5[['Importations (Milliers de tonnes)','Disponibilité alimentaire (Kcal/personne/jour)','Évolution Population(%)','Évolution Pib(%)','Stabilité politique']].sort_values(by='Importations (Milliers de tonnes)',ascending=False)

# %%
selection.style.set_caption("Sélection CAH").set_table_styles(styles).format(precision=2)
# Out:
# <style type="text/css">
# #T_195ca caption {
#   font-size: 150%;
#   font-weight: bold;
# }
# </style>
# <table id="T_195ca">
#   <caption>Sélection CAH</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_195ca_level0_col0" class="col_heading level0 col0" >Importations (Milliers de tonnes)</th>
#       <th id="T_195ca_level0_col1" class="col_heading level0 col1" >Disponibilité alimentaire (Kcal/personne/jour)</th>
#       <th id="T_195ca_level0_col2" class="col_heading level0 col2" >Évolution Population(%)</th>
#       <th id="T_195ca_level0_col3" class="col_heading level0 col3" >Évolution Pib(%)</th>
#       <th id="T_195ca_level0_col4" class="col_heading level0 col4" >Stabilité politique</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Zone</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_195ca_level0_row0" class="row_heading level0 row0" >Japon</th>
#       <td id="T_195ca_row0_col0" class="data row0 col0" >1069.00</td>
#       <td id="T_195ca_row0_col1" class="data row0 col1" >67.00</td>
#       <td id="T_195ca_row0_col2" class="data row0 col2" >-0.63</td>
#       <td id="T_195ca_row0_col3" class="data row0 col3" >-5.00</td>
#       <td id="T_195ca_row0_col4" class="data row0 col4" >1.11</td>
#     </tr>
#     <tr>
#       <th id="T_195ca_level0_row1" class="row_heading level0 row1" >Mexique</th>
#       <td id="T_195ca_row1_col0" class="data row1 col0" >972.00</td>
#       <td id="T_195ca_row1_col1" class="data row1 col1" >123.00</td>
#       <td id="T_195ca_row1_col2" class="data row1 col2" >5.01</td>
#       <td id="T_195ca_row1_col3" class="data row1 col3" >-13.49</td>
#       <td id="T_195ca_row1_col4" class="data row1 col4" >-0.72</td>
#     </tr>
#     <tr>
#       <th id="T_195ca_level0_row2" class="row_heading level0 row2" >Chine - RAS de Hong-Kong</th>
#       <td id="T_195ca_row2_col0" class="data row2 col0" >907.00</td>
#       <td id="T_195ca_row2_col1" class="data row2 col1" >210.00</td>
#       <td id="T_195ca_row2_col2" class="data row2 col2" >3.07</td>
#       <td id="T_195ca_row2_col3" class="data row2 col3" >20.09</td>
#       <td id="T_195ca_row2_col4" class="data row2 col4" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_195ca_level0_row3" class="row_heading level0 row3" >Allemagne</th>
#       <td id="T_195ca_row3_col0" class="data row3 col0" >842.00</td>
#       <td id="T_195ca_row3_col1" class="data row3 col1" >71.00</td>
#       <td id="T_195ca_row3_col2" class="data row3 col2" >1.83</td>
#       <td id="T_195ca_row3_col3" class="data row3 col3" >-3.11</td>
#       <td id="T_195ca_row3_col4" class="data row3 col4" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_195ca_level0_row4" class="row_heading level0 row4" >Royaume-Uni de Grande-Bretagne et d'Irlande du Nord</th>
#       <td id="T_195ca_row4_col0" class="data row4 col0" >779.00</td>
#       <td id="T_195ca_row4_col1" class="data row4 col1" >120.00</td>
#       <td id="T_195ca_row4_col2" class="data row4 col2" >2.68</td>
#       <td id="T_195ca_row4_col3" class="data row4 col3" >-6.84</td>
#       <td id="T_195ca_row4_col4" class="data row4 col4" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_195ca_level0_row5" class="row_heading level0 row5" >Arabie saoudite</th>
#       <td id="T_195ca_row5_col0" class="data row5 col0" >722.00</td>
#       <td id="T_195ca_row5_col1" class="data row5 col1" >151.00</td>
#       <td id="T_195ca_row5_col2" class="data row5 col2" >10.15</td>
#       <td id="T_195ca_row5_col3" class="data row5 col3" >-16.27</td>
#       <td id="T_195ca_row5_col4" class="data row5 col4" >-0.58</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **k-means**

# %%
from sklearn.cluster import KMeans
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import cluster, metrics
from scipy.spatial.distance import cdist

# %%
#Préparation des données pour le clustering K-Means
#Transformation en array Numpy
X = df.values

# %%
#Centrage / réduction des données

#Centrer les données est obligatoire pour une ACP => Centrer les données ne fait que déplacer (par une translation) le nuage de points de telle manière à ce que son centre de gravité coïncide avec l’origine du repère.
#Réduire est nécessaire car les variables ne sont pas  exprimées dans la même unité => accorder la même importance a chaque variable.
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %% [markdown]
# Determiner le nombre de cluster dans notre dataset

# %%
#Calcul  de la métrique "silhouette" pour différents nombres de groupes issus de la méthode des centres mobiles
#Liste pour stocker nos coefficients
silhouettes = [] 

#Boucle itérative de 2 à 10 (clusters) pour tester les possibilités
for k in range(2, 10): 
    #Création et ajustement d'un modèle pour chaque k
    cls = cluster.KMeans(n_clusters=k)  
    cls.fit(X_scaled)
    
    #Stockage des coefficients associés
    silh = metrics.silhouette_score(X_scaled, cls.labels_)
    silhouettes.append(silh)
    
#Visualisation des valeurs de coefficient de silhouette pour chaque nombre de cluster
plt.plot(range(2, 10), silhouettes, marker='o')
plt.title("Silhouette en fonction du nombre de clusters")
plt.xlabel('k')
plt.ylabel('Silhouette_score')
plt.savefig("KMeans_silhouette.png")
plt.show()

# %% [markdown]
# Le coeffficent est le plus elevé pour 3 clusters et décroît avec le nombre de cluster et remonte un peut pour 8.<p>
# Ce graphique indique qu'il faudrait privilégier 3 ou 5 clusters ceux pour lequel le coefficient de silhouette est le plus elevé

# %%
# k means determine k
distortions = []
K = range(2,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X_scaled)
    kmeanModel.fit(X_scaled)
    distortions.append(sum(np.min(cdist(X_scaled, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X_scaled.shape[0])
    
plt.plot(range(2, 10), distortions, marker='o')
plt.xlabel('k')
plt.ylabel('Distortion_score')
plt.title("Distortion en fonction du nombre de clusters")
plt.savefig("KMeans_distortion.png")
plt.show()

# %% [markdown]
# Le clustering ne s'améliore plus lorsque K augmente après 5.<p>
# On observe un décrochement (coude) suivi d’une décroissance régulière.<p>
# On sélectionne les axes avant le décrochement (k=4) .

# %%
#Clustering K-Means en 2 clusters
cls2 = cluster.KMeans(n_clusters=2)
cls2.fit(X_scaled)
y_kmeans2 = cls2.predict(X)

# %%
#Clustering K-Means en 3 clusters
cls3 = cluster.KMeans(n_clusters=3)
cls3.fit(X_scaled)
y_kmeans3 = cls3.predict(X)

# %%
#Clustering K-Means en 4 clusters
cls4 = cluster.KMeans(n_clusters=4)
cls4.fit(X_scaled)
y_kmeans4 = cls4.predict(X)

# %%
#Clustering K-Means en 5 clusters
cls5 = cluster.KMeans(n_clusters=5)
cls5.fit(X_scaled)
y_kmeans5 = cls5.predict(X)

# %%
#Récupération des clusters attribués à chaque individu (classes d'appartenance)
clusters_kmeans3 = cls3.labels_
clusters_kmeans5 = cls5.labels_

# %%
#Comparaison des clusters par les centroïdes (« centre » des clusters) (caractéristique moyenne du groupe)
centroids = cls4.cluster_centers_
df_centroides = pd.DataFrame(centroids, columns=df.columns)
df_centroides.style.set_caption("Centroïdes des classes").format(precision=2).highlight_max().set_table_styles(styles)
# Out:
# <style type="text/css">
# #T_dfa0a caption {
#   font-size: 150%;
#   font-weight: bold;
# }
# #T_dfa0a_row0_col2, #T_dfa0a_row1_col3, #T_dfa0a_row2_col4, #T_dfa0a_row3_col0, #T_dfa0a_row3_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_dfa0a">
#   <caption>Centroïdes des classes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfa0a_level0_col0" class="col_heading level0 col0" >Importations (Milliers de tonnes)</th>
#       <th id="T_dfa0a_level0_col1" class="col_heading level0 col1" >Disponibilité alimentaire (Kcal/personne/jour)</th>
#       <th id="T_dfa0a_level0_col2" class="col_heading level0 col2" >Évolution Population(%)</th>
#       <th id="T_dfa0a_level0_col3" class="col_heading level0 col3" >Évolution Pib(%)</th>
#       <th id="T_dfa0a_level0_col4" class="col_heading level0 col4" >Stabilité politique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfa0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfa0a_row0_col0" class="data row0 col0" >-0.09</td>
#       <td id="T_dfa0a_row0_col1" class="data row0 col1" >-0.49</td>
#       <td id="T_dfa0a_row0_col2" class="data row0 col2" >0.89</td>
#       <td id="T_dfa0a_row0_col3" class="data row0 col3" >-1.24</td>
#       <td id="T_dfa0a_row0_col4" class="data row0 col4" >-0.97</td>
#     </tr>
#     <tr>
#       <th id="T_dfa0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfa0a_row1_col0" class="data row1 col0" >-0.33</td>
#       <td id="T_dfa0a_row1_col1" class="data row1 col1" >-0.73</td>
#       <td id="T_dfa0a_row1_col2" class="data row1 col2" >0.47</td>
#       <td id="T_dfa0a_row1_col3" class="data row1 col3" >0.62</td>
#       <td id="T_dfa0a_row1_col4" class="data row1 col4" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_dfa0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfa0a_row2_col0" class="data row2 col0" >-0.20</td>
#       <td id="T_dfa0a_row2_col1" class="data row2 col1" >0.67</td>
#       <td id="T_dfa0a_row2_col2" class="data row2 col2" >-0.71</td>
#       <td id="T_dfa0a_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_dfa0a_row2_col4" class="data row2 col4" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_dfa0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfa0a_row3_col0" class="data row3 col0" >3.52</td>
#       <td id="T_dfa0a_row3_col1" class="data row3 col1" >0.69</td>
#       <td id="T_dfa0a_row3_col2" class="data row3 col2" >-0.41</td>
#       <td id="T_dfa0a_row3_col3" class="data row3 col3" >-0.11</td>
#       <td id="T_dfa0a_row3_col4" class="data row3 col4" >0.38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Je retiens le groupe 2 sur les mêmes critères que pour la CAH , des importations nettement supérieures aux autres groupes.

# %%
#Index trié des clusters
idk = np.argsort(cls4.labels_)

#Affichage des observations selon leurs clusters
df_cls4 = pd.DataFrame(df.index[idk], cls4.labels_[idk]).reset_index()
df_cls4 = df_cls4.rename(columns={'index':'Cluster_K'})

# %%
#Intégration des clusters dans notre dataframe "df_cls4" 
df_cls4 = pd.merge(df, df_cls4, on='Zone')

# %%
#Taille des clusters
print(str(len(df_cls4[df_cls4['Cluster_K'] == 0]['Cluster_K'])) + " pays dans le cluster 0")
print(str(len(df_cls4[df_cls4['Cluster_K'] == 1]['Cluster_K'])) + " pays dans le cluster 1")
print(str(len(df_cls4[df_cls4['Cluster_K'] == 2]['Cluster_K'])) + " pays dans le cluster 2")
print(str(len(df_cls4[df_cls4['Cluster_K'] == 3]['Cluster_K'])) + " pays dans le cluster 3")
# Out:
# 35 pays dans le cluster 0
# 53 pays dans le cluster 1
# 73 pays dans le cluster 2
# 10 pays dans le cluster 3

# %%
#Affichage des pays retenus dans ce clustering

print(df_cls4[df_cls4['Cluster_K'] == 2]['Zone'].unique())
# Out:
# ['Albanie' 'Antigua-et-Barbuda' 'Argentine' 'Australie' 'Autriche'
#  'Bahamas' 'Barbade' 'Belgique' 'Bolivie (État plurinational de)'
#  'Bosnie-Herzégovine' 'Brésil' 'Bulgarie' 'Bélarus' 'Cabo Verde' 'Canada'
#  'Chili' 'Chine - RAS de Macao' 'Chine, Taiwan Province de' 'Chypre'
#  'Costa Rica' 'Croatie' 'Cuba' 'Danemark' 'Dominique' 'El Salvador'
#  'Espagne' 'Estonie' 'Fidji' 'Finlande' 'Grenade' 'Grèce' 'Guyana'
#  'Géorgie' 'Hongrie' 'Irlande' 'Islande' 'Israël' 'Italie' 'Jamaïque'
#  'Kiribati' 'Lettonie' 'Lituanie' 'Luxembourg' 'Macédoine du Nord'
#  'Malaisie' 'Malte' 'Maurice' 'Monténégro' 'Myanmar' 'Norvège'
#  'Nouvelle-Calédonie' 'Nouvelle-Zélande' 'Panama' 'Pologne'
#  'Polynésie française' 'Portugal' 'Roumanie' 'République de Corée'
#  'République de Moldova' 'République dominicaine' 'Saint-Kitts-et-Nevis'
#  'Saint-Vincent-et-les Grenadines' 'Sainte-Lucie' 'Samoa' 'Serbie'
#  'Slovaquie' 'Slovénie' 'Suisse' 'Suède' 'Tchéquie' 'Trinité-et-Tobago'
#  'Uruguay' "États-Unis d'Amérique"]

# %%
#définir la "Zone" comme index
df_cls4.set_index('Zone', inplace=True)

# %%
#taille des clusters obtenus
sb.countplot(y=df_cls4.Cluster_K, data=df_cls4)
plt.title("Nombre de pays par groupe - Kmeans")
plt.savefig("Kmeans_nb_pays.png")
plt.show()

# %%
#Création d'un sous-ensemble avec sélection des pays du clusters 1 
df_cls4_select = df_cls4[df_cls4['Cluster_K'] == 2]
df_cls4_select.shape
# Out:
# (73, 6)

# %%
df_cls4_select=df_cls4_select[['Importations (Milliers de tonnes)','Disponibilité alimentaire (Kcal/personne/jour)','Évolution Population(%)','Évolution Pib(%)','Stabilité politique']].sort_values(by='Importations (Milliers de tonnes)',ascending=False)

# %%
#fonction pour mettre les index d'une liste en surbrillance
def color(s):

    return "background-color: yellow;" if s in ['Afrique du Sud','Chine, continentale','Pays-Bas','Émirats arabes unis'] else None

# %%
# Résultats du Kmeans comprarés aux résultats CAH (6 pays en commun + 4 en surbrillance)
df_cls4_select.style.set_caption("Sélection Kmeans").set_table_styles(styles).format(precision=2).applymap_index(color)
# Out:
# <style type="text/css">
# #T_bd6c0 caption {
#   font-size: 150%;
#   font-weight: bold;
# }
# </style>
# <table id="T_bd6c0">
#   <caption>Sélection Kmeans</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd6c0_level0_col0" class="col_heading level0 col0" >Importations (Milliers de tonnes)</th>
#       <th id="T_bd6c0_level0_col1" class="col_heading level0 col1" >Disponibilité alimentaire (Kcal/personne/jour)</th>
#       <th id="T_bd6c0_level0_col2" class="col_heading level0 col2" >Évolution Population(%)</th>
#       <th id="T_bd6c0_level0_col3" class="col_heading level0 col3" >Évolution Pib(%)</th>
#       <th id="T_bd6c0_level0_col4" class="col_heading level0 col4" >Stabilité politique</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Zone</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd6c0_level0_row0" class="row_heading level0 row0" >Belgique</th>
#       <td id="T_bd6c0_row0_col0" class="data row0 col0" >338.00</td>
#       <td id="T_bd6c0_row0_col1" class="data row0 col1" >44.00</td>
#       <td id="T_bd6c0_row0_col2" class="data row0 col2" >2.38</td>
#       <td id="T_bd6c0_row0_col3" class="data row0 col3" >-5.87</td>
#       <td id="T_bd6c0_row0_col4" class="data row0 col4" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row1" class="row_heading level0 row1" >Cuba</th>
#       <td id="T_bd6c0_row1_col0" class="data row1 col0" >312.00</td>
#       <td id="T_bd6c0_row1_col1" class="data row1 col1" >82.00</td>
#       <td id="T_bd6c0_row1_col2" class="data row1 col2" >0.50</td>
#       <td id="T_bd6c0_row1_col3" class="data row1 col3" >24.91</td>
#       <td id="T_bd6c0_row1_col4" class="data row1 col4" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row2" class="row_heading level0 row2" >Espagne</th>
#       <td id="T_bd6c0_row2_col0" class="data row2 col0" >205.00</td>
#       <td id="T_bd6c0_row2_col1" class="data row2 col1" >105.00</td>
#       <td id="T_bd6c0_row2_col2" class="data row2 col2" >-0.60</td>
#       <td id="T_bd6c0_row2_col3" class="data row2 col3" >-2.53</td>
#       <td id="T_bd6c0_row2_col4" class="data row2 col4" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row3" class="row_heading level0 row3" >Canada</th>
#       <td id="T_bd6c0_row3_col0" class="data row3 col0" >182.00</td>
#       <td id="T_bd6c0_row3_col1" class="data row3 col1" >154.00</td>
#       <td id="T_bd6c0_row3_col2" class="data row3 col2" >4.07</td>
#       <td id="T_bd6c0_row3_col3" class="data row3 col3" >-14.19</td>
#       <td id="T_bd6c0_row3_col4" class="data row3 col4" >1.10</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row4" class="row_heading level0 row4" >Chine, Taiwan Province de</th>
#       <td id="T_bd6c0_row4_col0" class="data row4 col0" >161.00</td>
#       <td id="T_bd6c0_row4_col1" class="data row4 col1" >126.00</td>
#       <td id="T_bd6c0_row4_col2" class="data row4 col2" >1.08</td>
#       <td id="T_bd6c0_row4_col3" class="data row4 col3" >0.35</td>
#       <td id="T_bd6c0_row4_col4" class="data row4 col4" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row5" class="row_heading level0 row5" >Chili</th>
#       <td id="T_bd6c0_row5_col0" class="data row5 col0" >155.00</td>
#       <td id="T_bd6c0_row5_col1" class="data row5 col1" >153.00</td>
#       <td id="T_bd6c0_row5_col2" class="data row5 col2" >5.12</td>
#       <td id="T_bd6c0_row5_col3" class="data row5 col3" >-5.32</td>
#       <td id="T_bd6c0_row5_col4" class="data row5 col4" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row6" class="row_heading level0 row6" >Roumanie</th>
#       <td id="T_bd6c0_row6_col0" class="data row6 col0" >146.00</td>
#       <td id="T_bd6c0_row6_col1" class="data row6 col1" >66.00</td>
#       <td id="T_bd6c0_row6_col2" class="data row6 col2" >-2.38</td>
#       <td id="T_bd6c0_row6_col3" class="data row6 col3" >13.57</td>
#       <td id="T_bd6c0_row6_col4" class="data row6 col4" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row7" class="row_heading level0 row7" >République de Corée</th>
#       <td id="T_bd6c0_row7_col0" class="data row7 col0" >137.00</td>
#       <td id="T_bd6c0_row7_col1" class="data row7 col1" >62.00</td>
#       <td id="T_bd6c0_row7_col2" class="data row7 col2" >1.49</td>
#       <td id="T_bd6c0_row7_col3" class="data row7 col3" >16.72</td>
#       <td id="T_bd6c0_row7_col4" class="data row7 col4" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row8" class="row_heading level0 row8" >Danemark</th>
#       <td id="T_bd6c0_row8_col0" class="data row8 col0" >133.00</td>
#       <td id="T_bd6c0_row8_col1" class="data row8 col1" >112.00</td>
#       <td id="T_bd6c0_row8_col2" class="data row8 col2" >1.67</td>
#       <td id="T_bd6c0_row8_col3" class="data row8 col3" >-4.92</td>
#       <td id="T_bd6c0_row8_col4" class="data row8 col4" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row9" class="row_heading level0 row9" >États-Unis d'Amérique</th>
#       <td id="T_bd6c0_row9_col0" class="data row9 col0" >123.00</td>
#       <td id="T_bd6c0_row9_col1" class="data row9 col1" >219.00</td>
#       <td id="T_bd6c0_row9_col2" class="data row9 col2" >2.74</td>
#       <td id="T_bd6c0_row9_col3" class="data row9 col3" >13.32</td>
#       <td id="T_bd6c0_row9_col4" class="data row9 col4" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row10" class="row_heading level0 row10" >Tchéquie</th>
#       <td id="T_bd6c0_row10_col0" class="data row10 col0" >116.00</td>
#       <td id="T_bd6c0_row10_col1" class="data row10 col1" >82.00</td>
#       <td id="T_bd6c0_row10_col2" class="data row10 col2" >0.51</td>
#       <td id="T_bd6c0_row10_col3" class="data row10 col3" >2.75</td>
#       <td id="T_bd6c0_row10_col4" class="data row10 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row11" class="row_heading level0 row11" >Autriche</th>
#       <td id="T_bd6c0_row11_col0" class="data row11 col0" >110.00</td>
#       <td id="T_bd6c0_row11_col1" class="data row11 col1" >65.00</td>
#       <td id="T_bd6c0_row11_col2" class="data row11 col2" >3.08</td>
#       <td id="T_bd6c0_row11_col3" class="data row11 col3" >-5.88</td>
#       <td id="T_bd6c0_row11_col4" class="data row11 col4" >1.05</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row12" class="row_heading level0 row12" >Bulgarie</th>
#       <td id="T_bd6c0_row12_col0" class="data row12 col0" >108.00</td>
#       <td id="T_bd6c0_row12_col1" class="data row12 col1" >81.00</td>
#       <td id="T_bd6c0_row12_col2" class="data row12 col2" >-2.57</td>
#       <td id="T_bd6c0_row12_col3" class="data row12 col3" >8.84</td>
#       <td id="T_bd6c0_row12_col4" class="data row12 col4" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row13" class="row_heading level0 row13" >Irlande</th>
#       <td id="T_bd6c0_row13_col0" class="data row13 col0" >99.00</td>
#       <td id="T_bd6c0_row13_col1" class="data row13 col1" >100.00</td>
#       <td id="T_bd6c0_row13_col2" class="data row13 col2" >2.99</td>
#       <td id="T_bd6c0_row13_col3" class="data row13 col3" >38.16</td>
#       <td id="T_bd6c0_row13_col4" class="data row13 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row14" class="row_heading level0 row14" >Italie</th>
#       <td id="T_bd6c0_row14_col0" class="data row14 col0" >97.00</td>
#       <td id="T_bd6c0_row14_col1" class="data row14 col1" >65.00</td>
#       <td id="T_bd6c0_row14_col2" class="data row14 col2" >0.84</td>
#       <td id="T_bd6c0_row14_col3" class="data row14 col3" >-9.15</td>
#       <td id="T_bd6c0_row14_col4" class="data row14 col4" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_bd6c0_level0_row15" class="row_heading level0 row15" >Suède</th>
#       <td id="T_bd6c0_row15_col0" class="data row15 col0" >84.00</td>
#       <td id="T_bd6c0_row15_col1" class="data row15 col1" >61.00</td>
#       <td id="T_bd6c0_row15_col2" class="data

# %% [markdown]
# ## Visualisation des clusters en ACP pour la projection des données

# %% [markdown]
# reduire  la dimension du dataframe a 2 composantes principales afin de pouvoir visuliser le resultat dans un plan 2D

# %%
#Calcul des composantes principales (coordonées des individus sur les axes de rang)
pca = decomposition.PCA(svd_solver='full')
pca.fit(X_scaled)
# Out:
# PCA(svd_solver='full')

# %%
#Pourcentage de variance expliquée par les composantes principales à l'aide de .explained_variance_ratio_
print(pca.explained_variance_ratio_)
# Out:
# [0.37758007 0.2257388  0.16509105 0.12454459 0.10704549]

# %% [markdown]
# La première composante explique environ 38% de la variance observée dans les données, la deuxième explique 22%.<p>
# Les 2 premières composantes principales expliquent 60% de la variance.

# %%
#Représentation de la variance expliquée en fonction du nombre de composantes (information = inertie = variance a plusieurs dimensions)
pca = decomposition.PCA()
pca.fit(X_scaled)
scree = pca.explained_variance_ratio_*100

plt.bar(np.arange(len(scree))+1, scree)
plt.plot(np.arange(len(scree))+1, scree.cumsum(),c="red",marker='o')
    
plt.xlabel("valeurs propre")
plt.ylabel("% cumulé de chaque valeurs propre")
plt.title("Eboulis des valeurs propres - cumulées")
plt.savefig("Eboulis des valeurs propres.png")
plt.show()

# %% [markdown]
# L’examen des plans factoriels permet de visualiser les corrélations entre les variables et d’identifier les groupes d’individus

# %%
## Projection des individus
plt.figure(figsize=(20, 10))

X_projected = pca.transform(X_scaled)

plt.subplot(121)
plt.scatter(X_projected[:, 0], X_projected[:, 1], c=cls3.labels_)
plt.xlabel('Composante {} ({}%)'.format(1, round(100*pca.explained_variance_ratio_[0],1)))
plt.ylabel('Composante {} ({}%)'.format(2, round(100*pca.explained_variance_ratio_[1],1)))
plt.title("Projection en 3 clusters des {} individus sur le 1er plan factoriel".format(X_projected.shape[0]))

plt.subplot(122)
plt.scatter(X_projected[:, 0], X_projected[:, 1], c=cls5.labels_)
plt.xlabel('Composante {} ({}%)'.format(1, round(100*pca.explained_variance_ratio_[0],1)))
plt.ylabel('Composante {} ({}%)'.format(2, round(100*pca.explained_variance_ratio_[1],1)))
plt.title("Projection en 5 clusters des {} individus sur le 1er plan factoriel".format(X_projected.shape[0]))

plt.savefig("Projection_3+5_clusters.png")
plt.show()

# %%
#Projection des 4 clusters sur le premier plan factoriel (F1, F2)


plt.figure(figsize=(20, 15))

plt.scatter(X_projected[:, 0], X_projected[:, 1], c=cls4.labels_)
for i,(x,y) in enumerate(X_projected[:,[0,1]]):
                    plt.text(x, y, df.index[i], fontsize='13') 

plt.xlabel('Composante{} ({}%)'.format(1, round(100*pca.explained_variance_ratio_[0],1)), fontsize=15)
plt.ylabel('Composante{} ({}%)'.format(2, round(100*pca.explained_variance_ratio_[1],1)), fontsize=15)
plt.title("Projection en 4 clusters des {} individus sur le 1er plan factoriel".format(X_projected.shape[0]), fontsize=20)

plt.savefig("Projection_cluster_4.png")
plt.show()

# %%
#Cercle des corrélations de nos variables
pcs = pca.components_

fig = plt.subplots(figsize=(10,10))
plt.xlim(-1,1)
plt.ylim(-1,1)

#Ajout des flèches
plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
           pcs[0,:], pcs[1,:], 
           angles='xy', scale_units='xy', scale=1, color='r', width= 0.003)

for i, (x, y) in enumerate(zip(pcs[0, :], pcs[1, :])):
    plt.text(x, y, df_cls4_select.columns[i])
    
circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
plt.gca().add_artist(circle)

#Ajout des axes
plt.plot([-1,1],[0,0],color='silver',linestyle='--',linewidth=1)
plt.plot([0,0],[-1,1],color='silver',linestyle='--',linewidth=1)

plt.title('Cercle des corrélations', fontsize=20)
plt.xlabel('Composante{} ({}%)'.format(1, round(100*pca.explained_variance_ratio_[0],1)))
plt.ylabel('Composante{} ({}%)'.format(2, round(100*pca.explained_variance_ratio_[1],1)))

plt.savefig("Cercle des corrélations K1.png")
plt.show()

# %% [markdown]
# Auncunes variables n'est fortement corrélées a un axe (proche d'un axe) ni bien représentés (proche du cercle).<p>
# Les variables Évolution Population , Disponibilité alimentaire et Stabilité politique sont moyennement corrélées a l'axe 1.<p>
# Les variables Importation et Évolution Pib sont moyennement corrélées a l'axe 2.

# %% [markdown]
# >Variables non liées ( les flèches forment un angle droit):
# >>Importation et Évolution Population / Importation et Stabilité politique / Disponibilité alimentaire et Évolution Pib

# %% [markdown]
# >Relations négatives (les flèches forment un angle obtus):
# >>quand la population augmente la disponibilité alimentaire  diminue<p>
# >>quand les importations  augmentent le Pib diminue

# %% [markdown]
# ## Séléction finale

# %%
selection.style.set_caption("Sélection finale").set_table_styles(styles).format(precision=2)
# Out:
# <style type="text/css">
# #T_5f2ab caption {
#   font-size: 150%;
#   font-weight: bold;
# }
# </style>
# <table id="T_5f2ab">
#   <caption>Sélection finale</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f2ab_level0_col0" class="col_heading level0 col0" >Importations (Milliers de tonnes)</th>
#       <th id="T_5f2ab_level0_col1" class="col_heading level0 col1" >Disponibilité alimentaire (Kcal/personne/jour)</th>
#       <th id="T_5f2ab_level0_col2" class="col_heading level0 col2" >Évolution Population(%)</th>
#       <th id="T_5f2ab_level0_col3" class="col_heading level0 col3" >Évolution Pib(%)</th>
#       <th id="T_5f2ab_level0_col4" class="col_heading level0 col4" >Stabilité politique</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Zone</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f2ab_level0_row0" class="row_heading level0 row0" >Japon</th>
#       <td id="T_5f2ab_row0_col0" class="data row0 col0" >1069.00</td>
#       <td id="T_5f2ab_row0_col1" class="data row0 col1" >67.00</td>
#       <td id="T_5f2ab_row0_col2" class="data row0 col2" >-0.63</td>
#       <td id="T_5f2ab_row0_col3" class="data row0 col3" >-5.00</td>
#       <td id="T_5f2ab_row0_col4" class="data row0 col4" >1.11</td>
#     </tr>
#     <tr>
#       <th id="T_5f2ab_level0_row1" class="row_heading level0 row1" >Mexique</th>
#       <td id="T_5f2ab_row1_col0" class="data row1 col0" >972.00</td>
#       <td id="T_5f2ab_row1_col1" class="data row1 col1" >123.00</td>
#       <td id="T_5f2ab_row1_col2" class="data row1 col2" >5.01</td>
#       <td id="T_5f2ab_row1_col3" class="data row1 col3" >-13.49</td>
#       <td id="T_5f2ab_row1_col4" class="data row1 col4" >-0.72</td>
#     </tr>
#     <tr>
#       <th id="T_5f2ab_level0_row2" class="row_heading level0 row2" >Chine - RAS de Hong-Kong</th>
#       <td id="T_5f2ab_row2_col0" class="data row2 col0" >907.00</td>
#       <td id="T_5f2ab_row2_col1" class="data row2 col1" >210.00</td>
#       <td id="T_5f2ab_row2_col2" class="data row2 col2" >3.07</td>
#       <td id="T_5f2ab_row2_col3" class="data row2 col3" >20.09</td>
#       <td id="T_5f2ab_row2_col4" class="data row2 col4" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_5f2ab_level0_row3" class="row_heading level0 row3" >Allemagne</th>
#       <td id="T_5f2ab_row3_col0" class="data row3 col0" >842.00</td>
#       <td id="T_5f2ab_row3_col1" class="data row3 col1" >71.00</td>
#       <td id="T_5f2ab_row3_col2" class="data row3 col2" >1.83</td>
#       <td id="T_5f2ab_row3_col3" class="data row3 col3" >-3.11</td>
#       <td id="T_5f2ab_row3_col4" class="data row3 col4" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_5f2ab_level0_row4" class="row_heading level0 row4" >Royaume-Uni de Grande-Bretagne et d'Irlande du Nord</th>
#       <td id="T_5f2ab_row4_col0" class="data row4 col0" >779.00</td>
#       <td id="T_5f2ab_row4_col1" class="data row4 col1" >120.00</td>
#       <td id="T_5f2ab_row4_col2" class="data row4 col2" >2.68</td>
#       <td id="T_5f2ab_row4_col3" class="data row4 col3" >-6.84</td>
#       <td id="T_5f2ab_row4_col4" class="data row4 col4" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_5f2ab_level0_row5" class="row_heading level0 row5" >Arabie saoudite</th>
#       <td id="T_5f2ab_row5_col0" class="data row5 col0" >722.00</td>
#       <td id="T_5f2ab_row5_col1" class="data row5 col1" >151.00</td>
#       <td id="T_5f2ab_row5_col2" class="data row5 col2" >10.15</td>
#       <td id="T_5f2ab_row5_col3" class="data row5 col3" >-16.27</td>
#       <td id="T_5f2ab_row5_col4" class="data row5 col4" >-0.58</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# >Pays commun au deux methodes de clustering qui ont les importations les plus importantes

# %% [markdown]
# >Les pays européens (Allemagne et Royaume-Uni) peuvent faire une première cible car le marché est accessible
